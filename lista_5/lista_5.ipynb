# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# As figuras que seguem ilustram um cachorro e um gr ́afico que mostra como  ́e a curva
# da sua parte superior. Os pontos apresentados na tabela que segue foram selecionados para
# gerar uma aproxima ̧c ̃ao para essa parte superior.

# %%
dados_de_entrada = np.array(
    [
        [1, 3.0],
        [2, 3.7],
        [5, 3.9],
        [6, 4.2],
        [7, 5.7],
        [8, 6.6],
        [10, 7.1],
        [13, 6.7],
        [17, 4.5],
        [20, 7.0],
        [23, 6.1],
        [24, 5.6],
        [25, 5.8],
        [27, 5.2],
        [27.7, 4.1],
        [28, 4.3],
        [29, 4.1],
        [30, 3.0],
    ]
)

# %% [markdown]
# ## Questão 1

# %%
def pol_lagrange(x_values, y_values, z):
    r = np.zeros(len(z))

    for i in range(len(x_values)):
        c = 1
        d = 1

        for j in range(len(x_values)):
            if i != j:
                c *= z - x_values[j]
                d *= x_values[i] - x_values[j]

        r += y_values[i] * (c / d)

    return r

# %%
interpol = np.linspace(1, 30, num=1000)

# %%
resultado = pol_lagrange(dados_de_entrada[:, 0], dados_de_entrada[:, 1], interpol)

plt.plot(interpol, resultado, label="interpolado")

plt.scatter(
    dados_de_entrada[:, 0],
    dados_de_entrada[:, 1],
    label="dados de entrada",
    color="r",
    marker="+",
    linewidths=1,
)

# Configurando os rótulos e título do gráfico
plt.xlabel("x")
plt.ylabel("f(x)")
plt.title("Forma de Lagrange")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Questão 2

# %%
class spline:
    def __init__(self):
        self.coeff = {"a": [], "b": [], "c": [], "d": []}
        self.polinomios = {"eq": [], "dominios": []}
        pass

    def fit(self, x, y):
        n = len(x)
        self.coeff["a"] = np.array([valor for valor in y])
        h = np.array([x[k + 1] - x[k] for k in range(n - 1)])

        # Criando matriz de coeficientes do
        # sistemas de equação para c

        A = np.zeros((n, n))

        A[0, 0] = 1  # Linha inicial

        for i in range(1, n - 1):  # Linhas internas da matriz A
            A[i, i - 1] = h[i - 1]

            A[i, i] = 2 * (h[i - 1] + h[i])

            A[i, i + 1] = h[i]

        A[n - 1, n - 1] = 1  # Linha final

        # Criando matriz de resultados do
        # sistemas de equação para c

        B = np.zeros(n)

        for k in range(1, n - 1):
            B[k] = (
                3 * (self.coeff["a"][k + 1] - self.coeff["a"][k]) / h[k]
                - 3 * (self.coeff["a"][k] - self.coeff["a"][k - 1]) / h[k - 1]
            )

        self.coeff["c"] = np.linalg.solve(A, B)

        s = {}

        # calculando coeficientes b e d

        for k in range(n - 1):
            self.coeff["b"].append(
                (1 / h[k]) * (self.coeff["a"][k + 1] - self.coeff["a"][k])
                - (h[k] / 3) * (2 * self.coeff["c"][k] + self.coeff["c"][k + 1])
            )

            self.coeff["d"].append(
                (self.coeff["c"][k + 1] - self.coeff["c"][k]) / (3 * h[k])
            )

            self.polinomios["eq"].append(
                f'{self.coeff["a"][k]}{self.coeff["b"][k]:+}*(x-{x[k]}){self.coeff["c"][k]:+}*(x-{x[k]})**2{self.coeff["d"][k]:+}*(x-{x[k]})**3'
            )

            self.polinomios["dominios"].append((x[k], x[k + 1]))

    def transform(self, x):
        r = []

        for value in x:
            for eq, (min_value, max_value) in zip(
                self.polinomios["eq"], self.polinomios["dominios"]
            ):
                if value >= min_value and value <= max_value:

                    def p(x):
                        return eval(eq)

                    r.append(p(value))

        return r

# %%
polinomios.polinomios
# Out:
# {'eq': ['3.0+0.7857236959348448*(x-1.0)+0.0*(x-1.0)**2-0.08572369593484462*(x-1.0)**3',
#   '3.7+0.5285526081303109*(x-2.0)-0.25717108780453385*(x-2.0)**2+0.03440303577221746*(x-2.0)**3',
#   '3.9-0.08559195284702065*(x-5.0)+0.05245623414542332*(x-5.0)**2+0.3331357187015976*(x-5.0)**3',
#   '4.2+1.0187276715486187*(x-6.0)+1.0518633902502161*(x-6.0)**2-0.5705910617988349*(x-6.0)**3',
#   '5.7+1.4106812666525463*(x-7.0)-0.6599097951462884*(x-7.0)**2+0.14922852849374155*(x-7.0)**3',
#   '6.6+0.5385472618411941*(x-8.0)-0.2122242096650638*(x-8.0)**2+0.03397528937223338*(x-8.0)**3',
#   '7.1+0.0973538956477395*(x-10.0)-0.008372473431663523*(x-10.0)**2-0.022841089854009115*(x-10.0)**3',
#   '6.7-0.5695903710004878*(x-13.0)-0.21394228211774557*(x-13.0)**2+0.05470996871696688*(x-13.0)**3',
#   '4.5+0.34494987047195785*(x-17.0)+0.442577342485857*(x-17.0)**2-0.09326095162179951*(x-17.0)**3',
#   '7.0+0.4823682315985131*(x-20.0)-0.3967712221103386*(x-20.0)**2+0.04532727052583363*(x-20.0)**3',
#   '6.1-0.6744227968660107*(x-23.0)+0.011174212622164038*(x-23.0)**2+0.16324858424384664*(x-23.0)**3',
#   '5.6-0.16232861889014277*(x-24.0)+0.500919965353704*(x-24.0)**2-0.13859134646356097*(x-24.0)**3',
#   '5.8+0.423737272426582*(x-25.0)+0.08514592596302104*(x-25.0)**2-0.22350728108815598*(x-25.0)**3',
#   '5.2-1.9177663967792054*(x-27.0)-1.255897760565915*(x-27.0)**2+2.500951546421988*(x-27.0)**3',
#   '4.1+0.0003755116688294313*(x-27.7)+3.9961004869202537*(x-27.7)**2-5.917099900869334*(x-27.7)**3',
#   '4.3+0.8004188305862594*(x-28.0)-1.3292894238621598*(x-28.0)**2+0.3288705932759*(x-28.0)**3',
#   '4.1-0.8715482373103598*(x-29.0)-0.3426776440344597*(x-29.0)**2+0.11422588134481991*(x-29.0)**3'],
#  'dominios': [(1.0, 2.0),
#   (2.0, 5.0),
#   (5.0, 6.0),
#   (6.0, 7.0),
#   (7.0, 8.0),
#   (8.0, 10.0),
#   (10.0, 13.0),
#   (13.0, 17.0),
#   (17.0, 20.0),
#   (20.0, 23.0),
#   (23.0, 24.0),
#   (24.0, 25.0),
#   (25.0, 27.0),
#   (27.0, 27.7),
#   (27.7, 28.0),
#   (28.0, 29.0),
#   (29.0, 30.0)]}

# %%
interpolador = spline()
polinomios = interpolador.fit(dados_de_entrada[:, 0], dados_de_entrada[:, 1])

resultado = interpolador.transform(interpol)

plt.plot(interpol, resultado, label="interpolado")

plt.scatter(
    dados_de_entrada[:, 0],
    dados_de_entrada[:, 1],
    label="dados de entrada",
    color="r",
    marker="+",
    linewidths=1,
)

# Configurando os rótulos e título do gráfico
plt.xlabel("x")
plt.ylabel("f(x)")
plt.title("Spline")
plt.legend()
plt.grid()
plt.show()
